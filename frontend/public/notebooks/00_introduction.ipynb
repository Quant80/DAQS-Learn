# %% [markdown]
# <div style='background: linear-gradient(135deg, #0f2027, #203a43, #2c5364); padding: 40px; border-radius: 16px; text-align: center; margin-bottom: 30px;'>
#   <h1 style='color: #00d4ff; font-size: 2.5em; margin: 0; text-shadow: 0 0 20px rgba(0,212,255,0.5);'>🐍 DAQSLearn Python Programming</h1>
#   <h2 style='color: #ffffff; font-size: 1.8em; margin: 15px 0 5px;'>Introduction — Fun-damentals of Python</h2>
#   <p style='color: #a0c4ff; font-size: 1.1em; margin: 0;'>Gateway for the Joy of Programming</p>
#   <div style='margin-top: 20px; display: flex; justify-content: center; gap: 20px; flex-wrap: wrap;'>
#     <span style='background: rgba(0,212,255,0.2); color: #00d4ff; padding: 6px 16px; border-radius: 20px; font-size: 0.9em;'>📚 Introduction</span>
#     <span style='background: rgba(0,212,255,0.2); color: #00d4ff; padding: 6px 16px; border-radius: 20px; font-size: 0.9em;'>🟢 Beginner</span>
#     <span style='background: rgba(0,212,255,0.2); color: #00d4ff; padding: 6px 16px; border-radius: 20px; font-size: 0.9em;'>⏱️ ~30 minutes</span>
#   </div>
# </div>

# %% [markdown]
# <div style='border: 2px solid #0077cc; border-radius: 12px; padding: 20px; background: #e8f4fd; margin-bottom: 20px;'>
#   <h3 style='color: #0077cc; margin-top: 0;'>🎯 What You Will Learn in This Notebook</h3>
#   <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 0 30px;'>
#   <ul>
#     <li>Why Python is the best first programming language</li>
#     <li>What programming is and why computers need it</li>
#     <li>The difference between machine language and programming languages</li>
#     <li>How compilers and interpreters work — and how they differ</li>
#     <li>What Python is, its history, and who created it</li>
#   </ul>
#   <ul>
#     <li>Key features that make Python special</li>
#     <li>10 real-world application areas of Python</li>
#     <li>What an IDE is and how to use Jupyter Notebook</li>
#     <li>What syntax means and what happens when you break rules</li>
#     <li>How to write and run your very first Python program</li>
#   </ul>
#   </div>
# </div>

# %% [markdown]
# ---
# ## 📖 Introduction
#
# > *"Everybody should learn to program a computer, because it teaches you how to think."*
# > — **Steve Jobs**
#
# Computer programming is used to solve problems. However it is still taught as boring theory and most beginners fail to learn — then they hate it.
#
# This course takes a different approach: **we learn by doing**. Every concept is followed immediately by working code you can run right here in Jupyter Notebook.
#
# ### Why Python?
#
# Python is an easy-to-learn programming language that has some really useful features for a beginner. The code is quite easy to read when compared to other programming languages, and you can solve and make almost anything with it.
#
# ### How to Learn to Code?
#
# Like anything you try for the first time, it's always best to start with the basics. Begin with the first chapters and **resist the urge to skip ahead** to the later chapters.
#
# > 💡 *The expert in anything was once a beginner.*
#
# If you jump ahead too quickly, not only will the basic ideas not stick in your head, but you'll also find the content of the later chapters more complicated than it actually is. Try **each of the examples** so you can see how they work.
#
# ### Who Should Read This?
#
# This course is for **everyone** — from complete newbies to experienced programmers looking for a refresher. By the time you reach the end, you'll be:
# - Writing your own programs
# - Solving puzzles
# - Ready to use other Python libraries and frameworks
#
# ### Have Fun!
#
# Think of programming as a way to create fun games or play puzzles with your friends. Learning to program is a wonderful mental exercise and the results can be very rewarding. Most importantly — **have fun!**

# %% [markdown]
# ---
# ## 📚 Course Overview — What You Will Study
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────────┐
# │                    FUN-DAMENTALS OF PYTHON PROGRAMMING                          │
# │                       Gateway for the Joy of Programming                        │
# ├────────────────────────────────┬────────────────────────────────────────────────┤
# │  Chapter                       │  Topics                                        │
# ├────────────────────────────────┼────────────────────────────────────────────────┤
# │  00  Introduction              │  Programming, Languages, Python basics          │
# │  01  Get Started               │  Compiler, Interpreter, IDE, Syntax            │
# │  02  Hello Python              │  Python history, features, applications         │
# │  03  Variables                 │  Variables, Keywords, Memory, Operations        │
# │  04  Data Types                │  None, bool, int, float, str, list, dict…      │
# │  05  Operators                 │  Arithmetic, Relational, Compound, Identity     │
# │  06  Conditional Statements    │  if, elif, else, Logical, Bitwise, Membership   │
# │  07  Functions                 │  def, return, Lambda, Decorators, Generators    │
# │  08  Strings                   │  Indexing, Slicing, Methods, Validation         │
# │  09  List and Tuple            │  List ops, Cloning, Tuple, Comparison           │
# │  10  Control Flow (Loops)      │  while, for, break, continue, Patterns          │
# │  11  Set                       │  Set operations, Venn diagrams, frozenset        │
# │  12  Dictionary                │  Key-value pairs, Methods, Comprehension         │
# │  13  Object Oriented (OOP)     │  Classes, Inheritance, Polymorphism, Abstraction│
# │  14  Exception Handling        │  try, except, finally, Custom exceptions         │
# └────────────────────────────────┴────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ---
# ## 💻 Lesson 1 — Introduction to Programming
#
# > *"Computers are dumb. Computers are only smart because we program them to be."*
#
# ### What is Programming?
#
# **Programming** is the process of preparing a set of step-by-step instructions that tells a computer exactly what to do — without making mistakes.
#
# Computers are powerful machines, but they cannot think, decide, or act on their own. They only do **exactly what we tell them**. Programming is how we communicate those instructions.
#
# ### What is a Programming Language?
#
# A **programming language** is a formal language — a set of instructions — that helps a programmer communicate or interact with a computer.
#
# There are **two types of languages** for communication between a computer and a programmer:
#
# ```
#   TYPES OF LANGUAGES
#   ┌─────────────────────────────────────────────────────────────────────────┐
#   │                                                                         │
#   │  1. Machine Language                                                    │
#   │     • Binary code (series of 0s and 1s)                                │
#   │     • Computers UNDERSTAND it                                           │
#   │     • Humans find it VERY DIFFICULT to read                             │
#   │     • Example: 01001000 01100101 01101100 01101100 01101111             │
#   │                                                                         │
#   │  2. Programming Language                                                │
#   │     • Source code (human-readable text)                                 │
#   │     • Humans UNDERSTAND it                                              │
#   │     • Computers CANNOT directly execute it                              │
#   │     • Example: print("Hello")                                          │
#   │                                                                         │
#   └─────────────────────────────────────────────────────────────────────────┘
#
#   Problem: We write in Programming Language, but computers need Machine Language.
#   Solution: We need a TRANSLATOR → Compiler or Interpreter
# ```
#
# ### High-Level vs Low-Level Languages
#
# Programming languages are grouped by how close they are to human language:
#
# ```
# ┌───────────────────────────────────────────────────────────────────────────┐
# │  HIGH-LEVEL Languages (Programmer Friendly)                               │
# │  • Humans can easily understand, maintain, and debug                      │
# │  • Examples: Python, Java, C, C++                                        │
# │                                                                           │
# │  LOW-LEVEL Languages (Machine Friendly)                                   │
# │  • Very close to binary — almost impossible for humans to read            │
# │  • Examples: Assembly language, Machine language                          │
# │                                                                           │
# │  PS. Computers only understand machine code (0s and 1s).                 │
# └───────────────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ---
# ## ⚙️ Lesson 2 — Compiler and Interpreter
#
# Both compilers and interpreters translate high-level programming language into machine code — but they do it differently.
#
# ### What is a Compiler?
#
# A **compiler** is a computer program that translates the **entire source code at once** into machine-executable code and creates an executable program. The processor then runs that executable file.
#
# ```
#   COMPILER FLOW:
#
#   Source Code  ──►  COMPILER  ──►  Executable File  ──►  Run
#   (all at once)     (translate)     (machine code)        (fast!)
#
#   • Languages: Java, C++
#   • Translated BEFORE running → FASTER at runtime
#   • If ONE error exists → NOTHING runs until ALL errors are fixed
# ```
#
# ### What is an Interpreter?
#
# An **interpreter** is a computer program that directly executes instructions written in a programming language **one line at a time**, without requiring prior compilation into machine code.
#
# ```
#   INTERPRETER FLOW:
#
#   Source Code  ──►  Line 1 translate + run
#                 ──►  Line 2 translate + run
#                 ──►  Line 3 translate + run   ← error here? stop and show error!
#                 ──►  ...
#
#   • Languages: Python, PHP, Ruby
#   • Translated WHILE running → SLOWER but errors show immediately
#   • Easier to test and debug interactively
# ```
#
# ### Compiler vs Interpreter — Comparison Table
#
# ```
# ┌──────────────────────────┬──────────────────────────────┬────────────────────────────────┐
# │  Feature                 │  Compiler                    │  Interpreter                   │
# ├──────────────────────────┼──────────────────────────────┼────────────────────────────────┤
# │  How it works            │  Translates ALL at once      │  Translates line by line        │
# │  Speed at runtime        │  Fast (pre-translated)       │  Slower (translates as it runs) │
# │  Error detection         │  All errors before running   │  Stops at first error           │
# │  Output                  │  Creates an executable file  │  No separate file created       │
# │  Debugging               │  Harder (batch errors)       │  Easier (one error at a time)   │
# │  Examples                │  Java, C++                   │  Python, PHP, Ruby              │
# └──────────────────────────┴──────────────────────────────┴────────────────────────────────┘
# ```
#
# ### 🎬 The Movie Analogy
#
# Imagine watching an Italian movie but you only understand English. You have two options:
#
# ```
#   Option 1: Watch the English DUBBED version
#   → All Italian has been converted to English UPFRONT
#   → You watch the whole thing in English
#   → This is like a COMPILER
#
#   Option 2: Watch the Italian movie with English SUBTITLES
#   → Italian plays SCENE BY SCENE, subtitles appear in real time
#   → Each scene is translated as it plays
#   → This is like an INTERPRETER
#
#   Python works like subtitles — it reads and runs your code one line at a time.
# ```

# %% [markdown]
# ---
# ## 🖥️ Lesson 3 — How to Write and Run Code
#
# ### What is an IDE?
#
# To write and run Python code, you need two things installed on your computer:
# 1. An **Editor** — a place to write your code
# 2. A **Compiler / Interpreter** — to translate and run your code
#
# An **IDE (Integrated Development Environment)** combines both into one application. It gives you a graphical interface to **write, run, debug, and convert** your source code to machine code.
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                     POPULAR PYTHON IDEs                                  │
# ├──────────────────────┬──────────────────────────────────────────────────┤
# │  IDE                 │  Best for                                        │
# ├──────────────────────┼──────────────────────────────────────────────────┤
# │  Jupyter Notebook    │  Data science, learning, interactive code ✅ WE USE THIS │
# │  VS Code             │  General-purpose development                     │
# │  PyCharm             │  Professional Python development                 │
# │  IDLE                │  Beginners — comes built-in with Python           │
# │  Google Colab        │  Free cloud notebooks (no install needed)        │
# └──────────────────────┴──────────────────────────────────────────────────┘
# ```
#
# ### What is Syntax?
#
# Each programming language has its own set of **rules** called **syntax** — the grammar of the language. You must follow syntax rules exactly for your program to run.
#
# ```
#   PS. Breaking programming rules will result in an ERROR.
#
#   English example:
#     ❌  Mens clothes are cheap.    → WRONG (missing apostrophe)
#     ✅  Men's clothes are cheap.   → CORRECT
#
#   Python example:
#     ❌  print("Hello"             → SyntaxError (missing closing bracket)
#     ✅  print("Hello")            → Correct
# ```

# %% [markdown]
# ---
# ## 🐍 Lesson 4 — What is Python?
#
# **Python** is a simple, general-purpose, dynamic, object-oriented, interpreted as well as compiled, high-level programming language.
#
# ```
# ┌──────────────────────┬──────────────────────────────────────────────────────────┐
# │  Property            │  What it means                                           │
# ├──────────────────────┼──────────────────────────────────────────────────────────┤
# │  Simple              │  Easy to learn and code — reads almost like English      │
# │  General Purpose     │  Can be used to build just about anything                │
# │  High-Level          │  Human-readable, easy to understand and debug            │
# │  Dynamic             │  No need to declare variable types — Python handles it   │
# │  Object-Oriented     │  Code can be organized around objects and classes        │
# │  Interpreted+Compiled│  Source code → Bytecode → PVM → Output                  │
# └──────────────────────┴──────────────────────────────────────────────────────────┘
# ```
#
# ### How Python Runs Your Code
#
# ```
#   Python Execution Flow:
#
#   ┌──────────────┐    ┌──────────────────┐    ┌──────────────┐    ┌──────────┐
#   │  Your Code   │───►│ Python Compiler  │───►│   Bytecode   │───►│   PVM    │───► Output
#   │  (source.py) │    │  (internal step) │    │  (.pyc file) │    │          │
#   └──────────────┘    └──────────────────┘    └──────────────┘    └──────────┘
#
#   PVM = Python Virtual Machine
#   The PVM is an interpreter that reads bytecode and executes it on YOUR specific
#   computer — whether Windows, Mac, or Linux. This makes Python PLATFORM INDEPENDENT.
# ```
#
# ### Why Study Python?
#
# ```
#   ┌───────────────────────────────────────────────────────────────────────┐
#   │  Python is:                                                           │
#   │  • One of the EASIEST programming languages to learn for beginners   │
#   │  • The FASTEST GROWING language in the world (Stack Overflow surveys) │
#   │  • Used across the MOST areas — web, AI, science, automation         │
#   │  • Used by massive companies:                                         │
#   │    Google, NASA, Netflix, Spotify, Instagram, Facebook               │
#   └───────────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ---
# ### 📅 History and Origin of Python
#
# ```
# ┌──────────────┬──────────────────────────────────────────────────────────────┐
# │  Year        │  Milestone                                                    │
# ├──────────────┼──────────────────────────────────────────────────────────────┤
# │  Early 1990s │  Development began in the Netherlands by Guido Van Rossum    │
# │              │  Derived from the ABC programming language                    │
# ├──────────────┼──────────────────────────────────────────────────────────────┤
# │  1991        │  First version publicly released                              │
# ├──────────────┼──────────────────────────────────────────────────────────────┤
# │  January     │  Python 1.0 released                                          │
# │  1994        │                                                               │
# ├──────────────┼──────────────────────────────────────────────────────────────┤
# │  October     │  Python 2.0 released — added garbage collection, Unicode     │
# │  2000        │                                                               │
# ├──────────────┼──────────────────────────────────────────────────────────────┤
# │  December    │  Python 3.0 released — major redesign, not backward-         │
# │  2008        │  compatible with Python 2                                     │
# ├──────────────┼──────────────────────────────────────────────────────────────┤
# │  Feb 2024    │  Python 3.12 — current stable version                        │
# └──────────────┴──────────────────────────────────────────────────────────────┘
# ```
#
# <div style='border: 2px solid #fd7e14; border-radius: 12px; padding: 15px; background: #fff8f0; margin: 15px 0;'>
#   <strong style='color: #fd7e14;'>⚠️ Important:</strong> Python 3 does NOT provide backward compatibility to Python 2. There is no guarantee that Python 2 programs will run in Python 3. This course uses <strong>Python 3</strong>.
# </div>
#
# ### Why the Name "Python"?
#
# There was a TV show called **"Monty Python's Flying Circus"** — a very popular fun show in the 1970s. While creating Python, Guido also used to read this show's published scripts. He needed a short and unique name for the language, so he named it **"Python"** — after the show, not the snake!

# %% [markdown]
# ---
# ### ✨ Features of Python
#
# ```
# ┌────────────────────────────────────────────────────────────────────────────┐
# │                        KEY FEATURES OF PYTHON                              │
# ├────────────────────────┬───────────────────────────────────────────────────┤
# │  Feature               │  Description                                      │
# ├────────────────────────┼───────────────────────────────────────────────────┤
# │  Simple                │  Syntax is very easy to develop and understand    │
# │  Open Source           │  Download freely and customise the code           │
# │  Platform Independent  │  Runs on Windows, Mac, and Linux without changes  │
# │  Portable              │  Same code gives same results on any platform     │
# │  Huge Library          │  Thousands of built-in and third-party packages   │
# │  Database Connectivity │  Connects to Oracle, MySQL, PostgreSQL and more   │
# └────────────────────────┴───────────────────────────────────────────────────┘
#
#   Simplicity demo — printing "Hello World":
#
#   In C language (7 lines!):          In Python (1 line!):
#   ┌─────────────────────┐            ┌──────────────────────┐
#   │ #include <stdio.h>  │            │                      │
#   │ int main()          │            │  print("Hello World")│
#   │ {                   │            │                      │
#   │   printf("Hello");  │            └──────────────────────┘
#   │   return 0;         │
#   │ }                   │
#   └─────────────────────┘
# ```

# %% [markdown]
# ---
# ## 🌍 Lesson 5 — Applications of Python
#
# Python is a programming language that does it all. In this lesson, we take a deeper dive into the 10 major application areas:
#
# ```
# ┌────┬──────────────────────────────┬────────────────────────────┬──────────────────────────┐
# │ #  │  Application Area            │  Python Tools              │  Real Examples           │
# ├────┼──────────────────────────────┼────────────────────────────┼──────────────────────────┤
# │ 1  │  Web Development             │  Flask, Django             │  Instagram, Pinterest    │
# │ 2  │  Game Development            │  PyGame                    │  2D/3D video games       │
# │ 3  │  AI & Machine Learning       │  TensorFlow, PyTorch,      │  YouTube recommendations │
# │    │                              │  Pandas, Scikit-Learn      │  Self-driving cars       │
# │ 4  │  Desktop & Mobile Apps       │  Tkinter, Kivy             │  GUI desktop apps        │
# │ 5  │  Image Processing            │  OpenCV, PIL               │  Face recognition        │
# │    │                              │                            │  Image detection         │
# │ 6  │  Text Processing / NLP       │  NLTK, SpaCy               │  Facebook hate speech    │
# │    │                              │                            │  detection, chatbots     │
# │ 7  │  Audio & Video Applications  │  Pyo, pyAudioAnalysis      │  Spotify, Netflix,       │
# │    │                              │  OpenCV, SciPy             │  YouTube                 │
# │ 8  │  Web Scraping                │  BeautifulSoup, Selenium   │  Price tracking,         │
# │    │                              │  Requests                  │  News aggregators        │
# │ 9  │  Data Science & Visualization│  Matplotlib, Seaborn,      │  Dashboards, business    │
# │    │                              │  Pandas                    │  intelligence            │
# │ 10 │  Scientific & Numeric        │  SciPy, FreeCAD, Abaqus    │  Physics simulation,     │
# │    │                              │                            │  Engineering tools       │
# └────┴──────────────────────────────┴────────────────────────────┴──────────────────────────┘
# ```
#
# > Python is an extremely robust and versatile programming language that is rapidly gaining popularity among developers from all sectors. Its ability to be deployed into virtually any domain is remarkable, thanks to its vast ecosystem of diverse libraries.

# %% [markdown]
# ---
# ## 📓 Lesson 6 — Jupyter Notebook Installation and Usage
#
# **Jupyter Notebook** is an open-source web application to create and share live code. It is a popular IDE for data science and machine learning tasks. This is the IDE we use in this course.
#
# ### How to Install Jupyter Notebook
#
# <div style='font-family: monospace; background: #1e1e1e; color: #d4d4d4; border-radius: 10px; padding: 20px; margin: 15px 0; line-height: 2.2;'>
#   <div style='color: #9cdcfe; margin-bottom: 6px; letter-spacing: 0.05em;'>STEP-BY-STEP INSTALLATION:</div>
#   <div><span style='color: #9cdcfe;'>Step 1</span> &nbsp;→&nbsp; Visit &nbsp;<a href="https://www.anaconda.com/download" target="_blank" style='color: #4ec9b0; font-weight: bold; text-decoration: underline; background: rgba(78,201,176,0.12); padding: 1px 6px; border-radius: 4px;'>https://www.anaconda.com/download</a></div>
#   <div><span style='color: #9cdcfe;'>Step 2</span> &nbsp;→&nbsp; Select your operating system (Windows / Mac / Linux)</div>
#   <div><span style='color: #9cdcfe;'>Step 3</span> &nbsp;→&nbsp; Download the current Python version</div>
#   <div><span style='color: #9cdcfe;'>Step 4</span> &nbsp;→&nbsp; Open the downloaded file</div>
#   <div><span style='color: #9cdcfe;'>Step 5</span> &nbsp;→&nbsp; Click Continue</div>
#   <div><span style='color: #9cdcfe;'>Step 6</span> &nbsp;→&nbsp; Click 'Install for me only'</div>
#   <div><span style='color: #9cdcfe;'>Step 7</span> &nbsp;→&nbsp; Wait for: 'The installation was completed successfully'</div>
#   <div><span style='color: #9cdcfe;'>Step 8</span> &nbsp;→&nbsp; Click Close</div>
#   <div><span style='color: #9cdcfe;'>Step 9</span> &nbsp;→&nbsp; Open Anaconda Navigator → Launch Jupyter Notebook</div>
# </div>
#
# ### How to Write and Run Code on Jupyter Notebook
#
# ```
#   Step 1  → Open Anaconda Prompt
#   Step 2  → Navigate to your desired folder
#   Step 3  → Click New → Python 3
#   Step 4  → Write your code inside the cells
#   Step 5  → Press Shift + Enter to run your code
#   Step 6  → Output appears on the line below your code
# ```
#
# ### Jupyter Keyboard Shortcuts
#
# ```
# ┌─────────────────────────────────────┬──────────────────────────────────┐
# │  Action                             │  Shortcut                        │
# ├─────────────────────────────────────┼──────────────────────────────────┤
# │  Run current cell                   │  Shift + Enter                   │
# │  Run cell and stay                  │  Ctrl + Enter                    │
# │  Add new cell BELOW                 │  B  (in command mode)            │
# │  Add new cell ABOVE                 │  A  (in command mode)            │
# │  Delete cell                        │  D, D  (press D twice)           │
# │  Switch to command mode             │  Esc                             │
# │  Switch to edit mode                │  Enter                           │
# │  Switch cell to Markdown            │  M  (in command mode)            │
# │  Switch cell to Code                │  Y  (in command mode)            │
# │  Save notebook                      │  Ctrl + S                        │
# └─────────────────────────────────────┴──────────────────────────────────┘
# ```

# %% [markdown]
# ---
# ## 💻 Lesson 7 — Your First Python Programs
#
# ### The `print()` Function
#
# `print()` is Python's built-in function for displaying output on the screen. It is the **first and most used function** in Python.
#
# ```python
# print("your message here")        # print a text message
# print(variable_name)              # print a variable
# print("message", variable_name)   # print both together
# ```
#
# Run the cells below by clicking on them and pressing **`Shift + Enter`**:

# %%
# Your very first Python program
print("Hello World")

# %%
# print() can display any text message
print("I am learning Python!")
print("This is my second line.")
print("Python is fun.")

# %%
# print() can also display numbers and arithmetic results
print(2024)
print(3.14)
print(10 + 5)
print(2 ** 10)   # 2 to the power of 10

# %%
# print() can display multiple values separated by commas
print("Python was created by", "Guido van Rossum", "in", 1991)
print("Python version:", 3.12)

# %%
# Comparing Python to C — same output, very different effort:

# In C, you would need 6 lines:
# #include <stdio.h>
# int main() {
#     printf("Hello World");
#     return 0;
# }

# In Python — just ONE line:
print("Hello World")

# This is why Python is the recommended starting language.

# %% [markdown]
# ### What Happens When You Break Syntax Rules?
#
# Python is strict about syntax. If you break the rules, it shows an error immediately.
#
# <div style='border: 2px solid #fd7e14; border-radius: 12px; padding: 15px; background: #fff8f0; margin: 15px 0;'>
#   <strong style='color: #fd7e14;'>⚠️ Reading Error Messages:</strong> Always read the <strong>last line</strong> of any error message — it tells you exactly what went wrong. For example: <code>SyntaxError: '(' was never closed</code> means you forgot to close a bracket.
# </div>

# %%
# This will produce a SyntaxError — the closing parenthesis is missing
# Uncomment the line below to see the error:

# print("Hello World"

# Expected error:
#   SyntaxError: '(' was never closed

print("Try uncommenting the line above to see what a SyntaxError looks like.")

# %% [markdown]
# ---
# ## ✏️ Practice Exercises

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 1 — Print Your Name</h4>
#   <p>Use <code>print()</code> to display your full name on the screen.</p>
# </div>

# %%
# Write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 2 — Three Lines of Output</h4>
#   <p>Print three separate lines — your name, your age, and your favourite subject.</p>
# </div>

# %%
# Write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 3 — Python Facts</h4>
#   <p>Use a single <code>print()</code> call with commas to display:<br>
#   <code>Python was invented in 1991 in the Netherlands by Guido van Rossum</code></p>
# </div>

# %%
# Write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 4 — Python Applications</h4>
#   <p>Print a table of at least 3 Python application areas and one real-world tool for each.</p>
# </div>

# %%
# Example structure:
print("Application Area     | Tool")
print("---------------------+----------------")
# Add your rows below:

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 5 — Compiler or Interpreter?</h4>
#   <p>Is Python a compiled language or an interpreted language? Use <code>print()</code> to state your answer in a full sentence explaining how you can tell from running the cells above.</p>
# </div>

# %%
# Write your answer here
print("Python is ... because ...")

# %% [markdown]
# ---
# ## 🗝️ Key Takeaways
#
# <div style='border: 2px solid #6c757d; border-radius: 12px; padding: 20px; background: #f8f9fa; margin: 20px 0;'>
#   <table style='width:100%; border-collapse: collapse;'>
#     <tr style='background:#e9ecef;'><th style='padding:8px; text-align:left;'>Concept</th><th style='padding:8px; text-align:left;'>Key Point</th></tr>
#     <tr><td style='padding:8px;'><strong>Programming</strong></td><td style='padding:8px;'>The process of preparing an error-free set of instructions for a device</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Programming Language</strong></td><td style='padding:8px;'>A formal language to communicate with a computer through instructions</td></tr>
#     <tr><td style='padding:8px;'><strong>Machine Language</strong></td><td style='padding:8px;'>Binary (0s and 1s) — the only language computers understand directly</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Compiler</strong></td><td style='padding:8px;'>Translates ALL code at once into machine code before running (Java, C++)</td></tr>
#     <tr><td style='padding:8px;'><strong>Interpreter</strong></td><td style='padding:8px;'>Translates and runs code LINE BY LINE (Python, PHP, Ruby)</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>IDE</strong></td><td style='padding:8px;'>Integrated Development Environment — a graphical interface to write, run, and debug code</td></tr>
#     <tr><td style='padding:8px;'><strong>Syntax</strong></td><td style='padding:8px;'>The set of grammar rules for a programming language — breaking them causes errors</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Python</strong></td><td style='padding:8px;'>Simple, general-purpose, high-level, interpreted, open source language by Guido van Rossum</td></tr>
#     <tr><td style='padding:8px;'><strong>Python created</strong></td><td style='padding:8px;'>Early 1990s in the Netherlands; Python 1.0 in 1994; Python 3.0 in 2008</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Named after</strong></td><td style='padding:8px;'>TV show "Monty Python's Flying Circus" — NOT the snake!</td></tr>
#     <tr><td style='padding:8px;'><strong>Python execution</strong></td><td style='padding:8px;'>Source code → Compiler → Bytecode → PVM (interpreter) → Output</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Applications</strong></td><td style='padding:8px;'>Web, AI/ML, Data Science, Games, Image Processing, Web Scraping, Audio/Video, and more</td></tr>
#     <tr><td style='padding:8px;'><strong>print()</strong></td><td style='padding:8px;'>The fundamental Python function for displaying output to the screen</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Jupyter Notebook</strong></td><td style='padding:8px;'>Our IDE — write code in cells, run with Shift+Enter, output appears below</td></tr>
#   </table>
# </div>

# %% [markdown]
# <div style='background: linear-gradient(135deg, #1a1a2e, #16213e); padding: 25px; border-radius: 12px; text-align: center; margin-top: 30px;'>
#   <p style='color: #a0c4ff; margin: 0 0 10px;'>You have completed the Introduction to Python Programming</p>
#   <div style='display: flex; justify-content: center; gap: 30px; flex-wrap: wrap;'>
#     <span style='color: #666;'>← Start</span>
#     <span style='color: #00d4ff; font-weight: bold;'>📍 Introduction</span>
#     <span style='color: #666;'>Chapter 01: Get Started →</span>
#   </div>
#   <p style='color: #888; margin: 15px 0 0; font-size: 0.85em;'>DAQSLearn Platform | N³ Smart Solutions | Python Programming by Ncube.T</p>
# </div>
