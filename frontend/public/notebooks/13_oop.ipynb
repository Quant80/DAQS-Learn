# %% [markdown]
# <div style='background: linear-gradient(135deg, #0f2027, #203a43, #2c5364); padding: 40px; border-radius: 16px; text-align: center; margin-bottom: 30px;'>
#   <h1 style='color: #00d4ff; font-size: 2.5em; margin: 0; text-shadow: 0 0 20px rgba(0,212,255,0.5);'>🐍 DAQSLearn Python Programming</h1>
#   <h2 style='color: #ffffff; font-size: 1.8em; margin: 15px 0 5px;'>Chapter 13 — Object Oriented Programming</h2>
#   <p style='color: #a0c4ff; font-size: 1.1em; margin: 0;'>Modelling the Real World with Classes, Objects, and Inheritance</p>
#   <div style='margin-top: 20px; display: flex; justify-content: center; gap: 20px; flex-wrap: wrap;'>
#     <span style='background: rgba(0,212,255,0.2); color: #00d4ff; padding: 6px 16px; border-radius: 20px; font-size: 0.9em;'>📚 Chapter 13</span>
#     <span style='background: rgba(0,212,255,0.2); color: #00d4ff; padding: 6px 16px; border-radius: 20px; font-size: 0.9em;'>🔴 Advanced</span>
#     <span style='background: rgba(0,212,255,0.2); color: #00d4ff; padding: 6px 16px; border-radius: 20px; font-size: 0.9em;'>⏱️ ~150 minutes</span>
#   </div>
# </div>

# %% [markdown]
# <div style='border: 2px solid #0077cc; border-radius: 12px; padding: 20px; background: #e8f4fd; margin-bottom: 20px;'>
#   <h3 style='color: #0077cc; margin-top: 0;'>🎯 Chapter Objectives</h3>
#   <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 0 30px;'>
#   <ul>
#     <li>Understand the 3 programming paradigms</li>
#     <li>Define classes and create objects</li>
#     <li>Use constructors (parameterized &amp; non-parameterized)</li>
#     <li>Work with instance, static, and local variables</li>
#     <li>Define instance methods, class methods, and static methods</li>
#     <li>Use setter and getter methods</li>
#     <li>Apply encapsulation with public, protected, and private access</li>
#   </ul>
#   <ul>
#     <li>Use name mangling (<code>_</code> and <code>__</code> prefixes)</li>
#     <li>Create nested classes and understand garbage collection</li>
#     <li>Implement Single, Multilevel, and Multiple inheritance</li>
#     <li>Apply polymorphism: overriding, overloading, duck typing</li>
#     <li>Use the <code>super()</code> function</li>
#     <li>Create abstract classes and interfaces with <code>ABC</code></li>
#   </ul>
#   </div>
# </div>

# %% [markdown]
# ---
# ## 🏭 Lesson 1 — Introduction to Object-Oriented Programming
#
# ### The 3 Programming Paradigms
#
# A **programming paradigm** is a style or methodology for writing programs.
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                      PROGRAMMING PARADIGMS                                  │
# ├──────────────────────────┬──────────────────────────────────────────────────┤
# │  Paradigm                │  Description                                     │
# ├──────────────────────────┼──────────────────────────────────────────────────┤
# │  Functional Oriented     │  Programs built around FUNCTIONS. Functions      │
# │                          │  always return the same output for same input.   │
# ├──────────────────────────┼──────────────────────────────────────────────────┤
# │  Procedural Oriented     │  Step-by-step instructions (like a recipe).     │
# │                          │  Emphasizes executing instructions in order.     │
# ├──────────────────────────┼──────────────────────────────────────────────────┤
# │  Object Oriented (OOP)   │  Programs built around OBJECTS — reusable        │
# │                          │  pieces with data (attributes) and actions       │
# │                          │  (methods). Python supports both OOP and         │
# │                          │  functional styles.                              │
# └──────────────────────────┴──────────────────────────────────────────────────┘
# ```
#
# ### The TV Factory Analogy
#
# OOP concepts are easiest to understand through a real-world analogy:
#
# ```
#   TV FACTORY ANALOGY
#   ═══════════════════════════════════════════════════════════════
#
#   CLASS  ──►  Blueprint / Template  (the design for making a TV)
#               Defines:  brand, model, screen_size  ← attributes
#                         turn_on(), change_channel() ← behaviours
#
#   OBJECT ──►  Actual TV manufactured from the blueprint
#               salon_tv   = Television("Sony",    "X80K", 65)
#               bedroom_tv = Television("Samsung", "N5300", 32)
#
#               Each TV is a SEPARATE object with its OWN data
#               but shares the same CLASS structure.
#
#   CONSTRUCTOR ──►  The factory line that builds each TV object.
#                    Runs AUTOMATICALLY when a new object is created.
#   ═══════════════════════════════════════════════════════════════
# ```
#
# ### Key OOP Terms
#
# ```
# ┌────────────────┬──────────────────────────────────────────────────────────┐
# │  Term          │  Definition                                              │
# ├────────────────┼──────────────────────────────────────────────────────────┤
# │  Class         │  Blueprint / template for creating objects               │
# │  Object        │  A specific instance of a class                          │
# │  Attribute     │  Variable inside a class (data)                          │
# │  Method        │  Function inside a class (behaviour)                     │
# │  Constructor   │  Special method auto-called when object is created       │
# │  self          │  Default variable that refers to the current object      │
# └────────────────┴──────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ### What is `self`?
#
# `self` is a variable that always refers to **the current object** calling the method. It lets methods access their own object's data.
#
# ```
#   Why use self?
#   ┌─────────────────────────────────────────────────────────────┐
#   │  1. Access instance variables  →  self.brand, self.volume   │
#   │  2. Differentiate instance vs local variables               │
#   │  3. Call other methods on same object  →  self.method()     │
#   │  4. Identify which specific object is being acted on        │
#   └─────────────────────────────────────────────────────────────┘
#
#   Note: 'self' is a convention, not a keyword.
#         You could call it 'this' or 'tv' — but 'self' is standard.
# ```

# %%
# Ex 13.1 - Define a class (no output yet — no object created)
class Television:
    brand = "Sony"

    def turn_on(self):
        print(self.brand, "TV is on.")

print("Class defined. No output until we create an object.")

# %%
# Ex 13.2 - Creating an object
my_tv = Television()
print(my_tv)   # shows memory address by default

# %%
# Ex 13.3 - __str__() gives a human-readable string for the object
class Television:
    brand = "Sony"

    def turn_on(self):
        print(self.brand, "TV is on.")

    def __str__(self):
        return f"This is a {self.brand} Television object"

my_tv = Television()
print(my_tv)           # now calls __str__
print(type(my_tv))     # Ex 13.4

# %%
# Ex 13.5 - Calling methods and accessing variables
my_tv.turn_on()                    # via object name
Television.turn_on(my_tv)          # via class name (equivalent)
print("Brand:", my_tv.brand)       # accessing class variable

# %% [markdown]
# ---
# ## 🔧 Lesson 2 — Constructors
#
# A **constructor** is a special method (`__init__`) that runs **automatically** the moment an object is created. It is used to set up the object's initial state.
#
# ```
#   Syntax:
#
#       def __init__(self, [parameters]):
#           # initialization code
#
#   ┌──────────────────────────┬────────────────────────────────────────────┐
#   │  Constructor Type        │  Description                               │
#   ├──────────────────────────┼────────────────────────────────────────────┤
#   │  Non-parameterized       │  No arguments — uses default values        │
#   │  Parameterized           │  Takes arguments — sets custom values      │
#   └──────────────────────────┴────────────────────────────────────────────┘
#
#   Method vs Constructor:
#   ┌─────────────────────────┬──────────────────────────────────────────────┐
#   │  Method                 │  Constructor                                 │
#   ├─────────────────────────┼──────────────────────────────────────────────┤
#   │  Does operations        │  Initializes instance variables              │
#   │  Any name               │  Must be named __init__                      │
#   │  Called explicitly      │  Auto-called at object creation              │
#   └─────────────────────────┴──────────────────────────────────────────────┘
# ```

# %%
# Ex 13.6 - Non-parameterized Constructor (runs automatically)
class Television:
    def __init__(self):
        print("Constructor executed automatically at TV creation!")

my_tv = Television()   # constructor fires here

# %%
# Ex 13.8 - Non-parameterized constructor prints self (the object reference)
class Television:
    def __init__(self):
        print("Constructor executed.")
        print("self refers to:", self)

my_tv = Television()

# %%
# Ex 13.9 - Parameterized Constructor — pass values at creation
class Television:
    def __init__(self, brand, model, screen_size):
        self.brand = brand
        self.model = model
        self.screen_size = screen_size
        print(f"This TV is {brand} {screen_size}" + '" ' + f"{model}")

# Create MULTIPLE objects from the SAME class
salon_tv   = Television("Sony",    "Class X80K",       65)
bedroom_tv = Television("Samsung", "Class N5300 Series", 32)

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.1 — Bank Class</h4>
#   <p>Create a class called <code>Bank</code> with a <code>bank_name</code> property and a <code>display_bank()</code> method that prints the bank name. Create 2 different bank objects.</p>
# </div>

# %%
# Exercise 13.1 - write your code here

# %% [markdown]
# <div style='border: 2px solid #17a2b8; border-radius: 12px; padding: 20px; background: #e8f8fc; margin: 20px 0;'>
#   <h4 style='color: #17a2b8; margin-top: 0;'>🎯 Practice Zone — Lessons 1 & 2: Classes, Objects & Constructors</h4>
#   <p style='margin-bottom: 12px;'>Build fluency with class definitions, object creation, and constructors:</p>
#
#   <p><strong>🟢 Simple</strong></p>
#   <ol>
#     <li>Create a class <code>Dog</code> with a class variable <code>species = "Canis lupus"</code> and a method <code>bark()</code> that prints <code>"Woof!"</code>. Create 2 objects and call <code>bark()</code> on each.</li>
#     <li>Add a <code>__str__</code> method to a <code>Car</code> class so that <code>print(my_car)</code> outputs something like <code>"Toyota Corolla (2022)"</code>. Test with 2 different car objects.</li>
#     <li>Create a <code>Student</code> class with a non-parameterized constructor that prints <code>"New student enrolled!"</code>. Create 3 student objects and observe that the constructor fires each time.</li>
#   </ol>
#
#   <p><strong>🟡 Medium</strong></p>
#   <ol>
#     <li>Design a <code>Rectangle</code> class with a parameterized constructor that takes <code>width</code> and <code>height</code>. Add methods <code>area()</code>, <code>perimeter()</code>, and <code>is_square()</code>. Test with 3 rectangles.</li>
#     <li>Create a <code>Counter</code> class with a static variable <code>count = 0</code>. Each time a new object is created, the constructor increments <code>count</code>. Add a class method <code>get_count()</code> that returns the total number of objects ever created.</li>
#     <li>Build a <code>Contact</code> class with a parameterized constructor (<code>name, phone, email</code>). Add a <code>display()</code> method and a <code>__str__</code> representation. Create a list of 4 contacts and print them all with a loop.</li>
#   </ol>
#
#   <p><strong>🔴 Hard</strong></p>
#   <ol>
#     <li>Implement a <code>Vector2D</code> class with <code>x</code> and <code>y</code> coordinates. Override <code>__add__</code> to support <code>v1 + v2</code>, <code>__str__</code> for display, and add a <code>magnitude()</code> method. Test with several vectors.</li>
#     <li>Create a <code>Library</code> class that tracks books. Use a class variable <code>catalogue = []</code>. Add methods <code>add_book(title, author)</code>, <code>remove_book(title)</code>, <code>search(keyword)</code>, and <code>list_all()</code>. Test with 6 operations.</li>
#     <li>Build a <code>Matrix</code> class with a 2D list as data. Implement a parameterized constructor, a <code>display()</code> method, and a method <code>transpose()</code> that returns a new <code>Matrix</code> object with rows and columns swapped. Test with a 3×4 matrix.</li>
#   </ol>
# </div>

# %%
# Practice Zone — Lessons 1 & 2: write your solutions here

# %% [markdown]
# ---
# ## 📦 Lesson 3 — Class Variables and Methods
#
# ### Three Types of Variables in a Class
#
# ```
# ┌────────────────────────────────────────────────────────────────────────────┐
# │                      TYPES OF CLASS VARIABLES                              │
# ├───────────────────────┬──────────────────┬─────────────────────────────────┤
# │  Type                 │  Scope           │  Changes per object?            │
# ├───────────────────────┼──────────────────┼─────────────────────────────────┤
# │  Instance Variable    │  Object level    │  YES — each object has its own  │
# │  Static Variable      │  Class level     │  NO  — shared by all objects    │
# │  Local Variable       │  Method level    │  Only exists inside the method  │
# └───────────────────────┴──────────────────┴─────────────────────────────────┘
#
#   Instance Variable examples: brand, model, screen_size (differ per TV)
#   Static Variable examples:   display="LED" (all TVs use LED)
#   Local Variable examples:    min_volume, max_volume (temp, in one method)
# ```
#
# ### Three Types of Methods in a Class
#
# ```
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                      TYPES OF CLASS METHODS                                  │
# ├───────────────────────┬────────────────────┬─────────────────────────────────┤
# │  Type                 │  Decorator         │  First Parameter                │
# ├───────────────────────┼────────────────────┼─────────────────────────────────┤
# │  Instance Method      │  (none)            │  self  — acts on object data    │
# │  Class Method         │  @classmethod      │  cls   — acts on class data     │
# │  Static Method        │  @staticmethod     │  (none) — utility function      │
# └───────────────────────┴────────────────────┴─────────────────────────────────┘
# ```

# %%
# Ex 13.10 - Instance variables declared in a constructor
class Television:
    def __init__(self, brand, model, screen_size):
        self.brand = brand           # instance variable
        self.model = model           # instance variable
        self.screen_size = screen_size  # instance variable

salon_tv   = Television("Sony",    "Class X80K",        65)
bedroom_tv = Television("Samsung", "Class N5300 Series", 32)

print(salon_tv.__dict__)    # shows all instance variables as dict
print(bedroom_tv.__dict__)

# %% [markdown]
# <div style='border: 2px solid #6f42c1; border-radius: 12px; padding: 20px; background: #f5f0ff; margin: 20px 0;'>
#   <h4 style='color: #6f42c1; margin-top: 0;'>🏆 Challenge 1 — Shapes Calculator</h4>
#   <p>Build a shape hierarchy that combines <strong>abstract classes</strong>, <strong>inheritance</strong>, and <strong>polymorphism</strong>:</p>
#   <ul>
#     <li>Create an abstract base class <code>Shape</code> (import from <code>abc</code>) with:
#       <ul>
#         <li>Abstract methods: <code>area()</code> and <code>perimeter()</code></li>
#         <li>Concrete method <code>describe()</code> that prints the shape's name, area (2 d.p.), and perimeter (2 d.p.) — calling the abstract methods internally</li>
#         <li><code>__str__</code> that returns a one-line summary, e.g. <code>"Circle(r=5): area=78.54, perimeter=31.42"</code></li>
#       </ul>
#     </li>
#     <li>Implement three concrete subclasses:
#       <ul>
#         <li><code>Circle(Shape)</code>: accepts <code>radius</code>; use <code>math.pi</code>; area = πr²; perimeter = 2πr</li>
#         <li><code>Rectangle(Shape)</code>: accepts <code>width</code> and <code>height</code>; area = w × h; perimeter = 2(w + h)</li>
#         <li><code>Triangle(Shape)</code>: accepts three sides <code>a</code>, <code>b</code>, <code>c</code>; perimeter = a + b + c; area via Heron's formula: √(s(s-a)(s-b)(s-c)) where s = perimeter/2</li>
#       </ul>
#     </li>
#     <li>Create a list of <strong>6 mixed shapes</strong> and loop through calling <code>describe()</code> — demonstrating polymorphism</li>
#     <li>Write a standalone function <code>largest_shape(shapes)</code> that returns the shape with the greatest area</li>
#     <li>Write a standalone function <code>total_perimeter(shapes)</code> that sums all perimeters in the list</li>
#     <li><strong>Bonus:</strong> add a <code>Square(Rectangle)</code> subclass that only takes <code>side</code> — override <code>__str__</code> to show <code>"Square"</code> rather than <code>"Rectangle"</code></li>
#   </ul>
# </div>

# %%
# Challenge 1 - Shapes Calculator
import math
from abc import ABC, abstractmethod

# write your code here

# %% [markdown]
# <div style='border: 2px solid #6f42c1; border-radius: 12px; padding: 20px; background: #f5f0ff; margin: 20px 0;'>
#   <h4 style='color: #6f42c1; margin-top: 0;'>🏆 Challenge 2 — Employee Payroll System</h4>
#   <p>Design a payroll system that applies <strong>encapsulation</strong>, <strong>inheritance</strong>, <strong>method overriding</strong>, and <code>super()</code>:</p>
#   <ul>
#     <li><code>Employee</code> (base class):
#       <ul>
#         <li>Private attribute <code>__salary</code> with getter <code>get_salary()</code> and validated setter <code>set_salary(amount)</code> (must be positive)</li>
#         <li>Instance attributes: <code>name</code>, <code>employee_id</code></li>
#         <li>Static variable <code>company = "DAQSLearn Corp"</code></li>
#         <li>Abstract-style method <code>calculate_pay()</code> that child classes must override (raise <code>NotImplementedError</code>)</li>
#         <li><code>__str__</code> that returns <code>"[ID] Name — Type"</code></li>
#       </ul>
#     </li>
#     <li><code>FullTimeEmployee(Employee)</code>: <code>monthly_salary</code>; <code>calculate_pay()</code> returns monthly salary; overrides <code>__str__</code></li>
#     <li><code>PartTimeEmployee(Employee)</code>: <code>hourly_rate</code>, <code>hours_worked</code>; <code>calculate_pay()</code> returns <code>hourly_rate × hours_worked</code>; use <code>super().__init__()</code></li>
#     <li><code>Manager(FullTimeEmployee)</code>: adds <code>department</code> and <code>bonus</code>; <code>calculate_pay()</code> returns <code>monthly_salary + bonus</code>; use <code>super()</code> to call parent</li>
#     <li>Create a <code>Payroll</code> class that:
#       <ul>
#         <li>Holds a list of employees</li>
#         <li>Method <code>add_employee(emp)</code></li>
#         <li>Method <code>process_payroll()</code> that loops through all employees, calls <code>calculate_pay()</code> polymorphically, and prints each person's pay</li>
#         <li>Method <code>total_payroll_cost()</code> that returns the sum of all pay amounts</li>
#       </ul>
#     </li>
#     <li>Demonstrate with at least 2 full-time, 2 part-time, and 1 manager</li>
#     <li><strong>Bonus:</strong> add a <code>@classmethod company_info(cls)</code> on <code>Employee</code> that prints the company name and total headcount</li>
#   </ul>
# </div>

# %%
# Challenge 2 - Employee Payroll System
# write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.9 — Multiple Inheritance: Saving & Checking Accounts</h4>
#   <p>Create a <code>BankAccount</code> parent class, then use <strong>multiple inheritance</strong> to build specialised account types:</p>
#   <ul>
#     <li><code>BankAccount</code>: <code>account_number</code>, <code>balance</code>, methods <code>deposit(amount)</code> and <code>get_balance()</code></li>
#     <li><code>SavingAccount(BankAccount)</code>: adds <code>interest_rate</code>, <code>calculate_interest()</code>, and overrides <code>withdraw(amount)</code> to enforce a minimum balance of R500</li>
#     <li><code>CheckingAccount(BankAccount)</code>: adds <code>overdraft_limit</code>, overrides <code>withdraw(amount)</code> to allow going R1000 into the negative</li>
#     <li>Demonstrate all methods on each account type and show how withdrawal behaviour differs between the two child classes</li>
#   </ul>
# </div>

# %%
# Exercise 13.9 - write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.11 — Duck Typing: Universal Transaction Interface</h4>
#   <p>Build a banking system that uses <strong>duck typing</strong> to handle different account types through a common function:</p>
#   <ul>
#     <li><code>BankAccount</code>: <code>account_number</code>, <code>balance</code>; methods <code>deposit(amount)</code>, <code>withdraw(amount)</code> (check sufficient funds), <code>get_balance()</code></li>
#     <li><code>DebitCard</code>: same <code>account_number</code>, <code>balance</code> structure; same method signatures but different internal behaviour (e.g., daily spending limit of R3000)</li>
#     <li><code>perform_transaction(account, amount, transaction_type)</code>: a standalone function that calls either <code>deposit()</code> or <code>withdraw()</code> on whatever object is passed — it never checks <em>what type</em> the account is, only that it has the method</li>
#     <li>Test: perform 3 deposits and 3 withdrawals on a mix of <code>BankAccount</code> and <code>DebitCard</code> objects. Print the balance after each operation.</li>
#     <li><strong>Bonus:</strong> add a <code>CryptoWallet</code> class (not related by inheritance at all) that also has <code>deposit</code>, <code>withdraw</code>, <code>get_balance</code>. Show that <code>perform_transaction()</code> works on it too — pure duck typing.</li>
#   </ul>
# </div>

# %%
# Exercise 13.11 - write your code here

# %% [markdown]
# <div style='border: 2px solid #17a2b8; border-radius: 12px; padding: 20px; background: #e8f8fc; margin: 20px 0;'>
#   <h4 style='color: #17a2b8; margin-top: 0;'>🎯 Practice Zone — Lessons 5, 6 & 7: Inheritance, Polymorphism & Abstraction</h4>
#   <p style='margin-bottom: 12px;'>Apply OOP's most powerful concepts in progressively complex scenarios:</p>
#
#   <p><strong>🟢 Simple</strong></p>
#   <ol>
#     <li>Create an <code>Animal</code> parent class with <code>name</code> and a <code>speak()</code> method that returns <code>"..."</code>. Create <code>Dog</code>, <code>Cat</code>, and <code>Cow</code> child classes that each override <code>speak()</code>. Call <code>speak()</code> on a list of mixed animals using a loop (polymorphism).</li>
#     <li>Create an abstract class <code>Shape</code> (using <code>ABC</code>) with an abstract method <code>area()</code>. Implement <code>Circle</code>, <code>Rectangle</code>, and <code>Triangle</code> as concrete classes. Calculate and print the area of each shape.</li>
#     <li>Add a <code>__str__</code> method to each shape in Question 2 so that <code>print(shape)</code> gives a readable description. Demonstrate that printing works polymorphically in a loop.</li>
#   </ol>
#
#   <p><strong>🟡 Medium</strong></p>
#   <ol>
#     <li>Create a <code>Vehicle</code> base class with <code>brand</code>, <code>speed</code>, and method <code>describe()</code>. Use <code>super()</code> to call the parent constructor from <code>Car(Vehicle)</code> and <code>Motorcycle(Vehicle)</code>. Each child adds its own specific attribute. Build a fleet of 4 vehicles and call <code>describe()</code> on all.</li>
#     <li>Implement <code>SavingAccount</code> and <code>CheckingAccount</code> both inheriting from <code>BankAccount</code>. Override <code>withdraw()</code> in each with different rules. Write a <code>process_withdrawal(account, amount)</code> function that works on both without checking types. Test with 4 withdrawals on mixed account types.</li>
#     <li>Design a <code>Notification</code> abstract class with abstract method <code>send(message)</code>. Implement <code>EmailNotification</code>, <code>SMSNotification</code>, and <code>PushNotification</code>. Write a <code>notify_all(notifiers, message)</code> function that sends to all of them. Demonstrate with a list of mixed notification types.</li>
#   </ol>
#
#   <p><strong>🔴 Hard</strong></p>
#   <ol>
#     <li>Build a <strong>plugin system</strong>: define an abstract <code>Plugin</code> class with abstract methods <code>activate()</code>, <code>deactivate()</code>, and <code>run(data)</code>. Implement 3 different plugins. Write a <code>PluginManager</code> that holds a list of plugins, activates all, runs them in sequence on some data, then deactivates all.</li>
#     <li>Implement a <strong>deep inheritance chain</strong>: <code>Entity → Character → Warrior → Paladin</code>. Each level adds unique attributes and overrides the <code>attack()</code> method, calling <code>super()</code> to chain upwards. Show the Method Resolution Order (MRO) using <code>Paladin.__mro__</code> and verify all ancestors are represented.</li>
#     <li>Create a <strong>payment gateway</strong> using duck typing: <code>PayPal</code>, <code>StripeCard</code>, and <code>CashPayment</code> all unrelated by inheritance but each implementing <code>charge(amount)</code>, <code>refund(amount)</code>, and <code>get_transaction_history()</code>. Write a <code>PaymentProcessor</code> class that accepts any of them and processes a list of amounts without caring about the gateway type.</li>
#   </ol>
# </div>

# %%
# Practice Zone — Lessons 5, 6 & 7: write your solutions here

# %%
# Ex 13.11/12 - Instance variables in methods and via object name
class Television:
    def __init__(self, brand, model, screen_size):
        self.brand = brand
        self.model = model
        self.screen_size = screen_size

    def display_details(self):
        self.resolution = "4K"    # instance variable created in method
        self.display_type = "LED"
        print("TV Details")
        print(f"  Model      : {self.brand} {self.model}")
        print(f"  Screen     : {self.screen_size}\"")
        print(f"  Display    : {self.resolution} {self.display_type}")

my_tv = Television("Sony", "Class X80K", 65)
my_tv.price = 2400              # instance variable via object name
my_tv.display_details()
print(my_tv.__dict__)

# %%
# Ex 13.14/21 - Static variables — shared by ALL objects
class Television:
    display   = "LED"           # static variable
    resolution = "4K"           # static variable
    width     = 16
    height    = 9
    brand     = "Sony"
    model     = "Class X80K"
    netflix_web_url = "https://netflix.com"

    def __init__(self):
        print("Display :", self.display, Television.resolution)  # two access styles

    def aspect_ratio(self):
        print("Aspect Ratio is", self.width, ":", Television.height)

    @classmethod
    def display_details(cls):
        print("TV Model :", cls.brand, Television.model)

    @staticmethod
    def connect_to_netflix():
        print("Connecting to", Television.netflix_web_url)

my_tv = Television()
my_tv.aspect_ratio()
my_tv.display_details()       # class method
my_tv.connect_to_netflix()    # static method
Television.connect_to_netflix()  # can also call via class name (no object needed)

# %%
# Ex 13.22 - Local Variables — exist only inside the method
class Television:
    volume = 15

    def volume_up(self):
        min_volume, max_volume = 0, 100   # LOCAL variables
        if Television.volume == max_volume:
            Television.volume = max_volume
        else:
            Television.volume += 1
        print("Volume :", Television.volume)

my_tv = Television()
my_tv.volume_up()

# Local variable 'max_volume' is NOT accessible outside:
try:
    print(max_volume)  # NameError!
except NameError as e:
    print("NameError:", e, "— local variables only exist inside their method")

# %% [markdown]
# ### Setter and Getter Methods
#
# ```
#   Setter (mutator)  — SETS a value to an instance variable
#       def set_channel(self, channel): self.channel = channel
#
#   Getter (accessor) — GETS (returns) the value of an instance variable
#       def get_channel(self): return self.channel
#
#   Why use them? Validate data before storing it.
#   Example: only allow channels that actually exist.
# ```

# %%
# Ex 13.24 - Setter and Getter methods
class Television:
    def __init__(self):
        self.channels = {1: "Aljezzira", 2: "BBC", 3: "CNN"}

    def change_channel(self, channel):   # SETTER — validates first
        if channel >= 1 and channel <= len(self.channels):
            self.channel = channel
            channel_name = self.get_channel()   # uses getter
            print("Now watching:", channel_name)
        else:
            print("Channel does not exist!")

    def get_channel(self):   # GETTER — returns the current channel name
        return self.channels[self.channel]

my_tv = Television()
my_tv.change_channel(2)   # valid
my_tv.change_channel(5)   # invalid

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.2 — BankAccount Class</h4>
#   <p>Create a <code>BankAccount</code> class with:</p>
#   <ul>
#     <li><code>bank_name</code> as a static variable</li>
#     <li><code>balance</code> as an instance variable (set in constructor)</li>
#     <li><code>calculate_balance()</code> method that applies 7% interest as a local variable</li>
#     <li>Setter to set balance, Getter to return balance</li>
#   </ul>
# </div>

# %%
# Exercise 13.2 - write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.4 — Account Number Validator</h4>
#   <p>Create an <code>AccountValidator</code> class that enforces these rules on account numbers using setter and getter methods:</p>
#   <ul>
#     <li>The account number must be exactly <strong>6 digits</strong> long</li>
#     <li>It must <strong>start with the digits '10'</strong> (e.g., <code>100345</code>)</li>
#     <li>The setter should validate both rules and print an appropriate error message if either fails</li>
#     <li>The getter returns the account number if valid, or <code>None</code> if it has never been set validly</li>
#     <li>Test with: <code>100345</code> (valid), <code>1234</code> (too short), <code>205678</code> (wrong prefix), <code>'abcdef'</code> (not a number)</li>
#   </ul>
# </div>

# %%
# Exercise 13.4 - write your code here

# %% [markdown]
# <div style='border: 2px solid #17a2b8; border-radius: 12px; padding: 20px; background: #e8f8fc; margin: 20px 0;'>
#   <h4 style='color: #17a2b8; margin-top: 0;'>🎯 Practice Zone — Lesson 3: Class Variables, Methods & Setter/Getter</h4>
#   <p style='margin-bottom: 12px;'>Practise the three variable types and method types:</p>
#
#   <p><strong>🟢 Simple</strong></p>
#   <ol>
#     <li>Create a <code>Circle</code> class with a static variable <code>pi = 3.14159</code> and a parameterized constructor for <code>radius</code>. Add instance method <code>area()</code> that uses <code>Circle.pi</code> and a local variable for the result. Print the area of 3 circles.</li>
#     <li>Create a <code>Temperature</code> class with a setter that only accepts values between <code>-273</code> (absolute zero) and <code>1000</code>. The getter returns the stored value or <code>'Not set'</code> if invalid. Test with 4 different values.</li>
#     <li>Write a <code>BankAccount</code> class with a <code>@staticmethod</code> called <code>swift_code()</code> that prints the bank's SWIFT code (a fixed string). Call it both via the class and via an object.</li>
#   </ol>
#
#   <p><strong>🟡 Medium</strong></p>
#   <ol>
#     <li>Build a <code>Classroom</code> class. Use a static variable to track <code>total_students</code> across all classrooms. Each classroom has its own <code>name</code> and <code>student_list</code>. Add <code>enroll(name)</code> and <code>unenroll(name)</code> that update both the local list and the class-level counter.</li>
#     <li>Create a <code>Product</code> class with private <code>__price</code>. Use a getter that returns the price formatted as <code>"R{price:.2f}"</code> and a setter that raises an error if price is negative. Apply a <code>@classmethod</code> called <code>from_string(cls, "name:price")</code> to parse a product from a string.</li>
#     <li>Design a <code>Timer</code> class with instance variable <code>duration</code> (seconds) and a <code>@staticmethod</code> called <code>format_time(seconds)</code> that converts to <code>"Xh Ym Zs"</code> format. Test with 3660, 90, and 7325 seconds.</li>
#   </ol>
#
#   <p><strong>🔴 Hard</strong></p>
#   <ol>
#     <li>Implement a <code>Singleton</code> design pattern: a class where only ONE instance can ever exist. Override <code>__new__</code> to check if an instance already exists and return it if so. Verify that <code>s1 is s2</code> returns <code>True</code>.</li>
#     <li>Build a <code>Config</code> class using only static and class methods (no instance needed). It stores a dictionary of settings as a class variable. Add <code>set(key, value)</code>, <code>get(key, default=None)</code>, <code>reset()</code>, and <code>all_settings()</code> methods. Test with 5 different settings.</li>
#     <li>Create a fully validated <code>Person</code> class: <code>name</code> (non-empty string), <code>age</code> (0–130 integer), <code>email</code> (must contain '@'). Each field has a setter that raises <code>ValueError</code> with a clear message on bad input. Add a <code>to_dict()</code> method that returns the person data as a dictionary.</li>
#   </ol>
# </div>

# %%
# Practice Zone — Lesson 3: write your solutions here

# %% [markdown]
# ---
# ## 🔒 Lesson 4 — Encapsulation, Name Mangling & Nested Classes
#
# ### What is Encapsulation?
#
# **Encapsulation** restricts direct access to an object's internal data, protecting it from accidental or unauthorised changes.
#
# ```
#   Benefits of Encapsulation:
#   ┌─────────────────────────────────────────────────────────────┐
#   │  1. Data Hiding    — users can't see internal details       │
#   │  2. Code Reusability — encapsulated code is easier to test  │
#   │  3. Security       — prevents unauthorised data access      │
#   └─────────────────────────────────────────────────────────────┘
#
#   Access Modifiers in Python (via naming convention):
#   ┌───────────────────┬──────────┬──────────────────────────────────────────┐
#   │  Access Level     │  Prefix  │  Accessible from                         │
#   ├───────────────────┼──────────┼──────────────────────────────────────────┤
#   │  Public           │  (none)  │  Anywhere (inside or outside class)      │
#   │  Protected        │  _       │  Inside class and its subclasses         │
#   │  Private          │  __      │  Only inside the class                   │
#   └───────────────────┴──────────┴──────────────────────────────────────────┘
#
#   Example:
#       self.channel  = "BBC"   # Public  — open to all
#       self._volume  = 15      # Protected — convention: treat with care
#       self.__brand  = "Sony"  # Private — name-mangled to _Television__brand
# ```

# %%
# Ex 13.25 - Public, protected, and private attributes & methods
class Television:
    def __init__(self):
        self.channel  = "BBC"   # Public
        self._volume  = 15      # Protected
        self.__brand  = "Sony"  # Private

    def turn_on(self):
        print(f"The {self.__brand} TV is now on.")  # private OK inside class

    def _change_channel(self, channel):   # protected method
        print(f"Channel changed to {channel}.")

    def __adjust_volume(self, volume):    # private method
        print(f"Volume adjusted to {volume}.")

my_tv = Television()
my_tv.turn_on()                   # works — public method
print(my_tv.channel)              # works — public attribute

# %%
# Ex 13.26 - Protected method can be called from outside (but shouldn't be)
my_tv._change_channel("CNN")   # works but discouraged

# Ex 13.27 - Private method CANNOT be called from outside
try:
    my_tv.__adjust_volume(30)  # AttributeError!
except AttributeError as e:
    print("AttributeError:", e)

# %%
# Ex 13.31 - Accessing private variable via a Getter method
class Television:
    def __init__(self):
        self.channel  = "BBC"
        self._volume  = 15
        self.__brand  = "Sony"   # private

    def turn_on(self):
        print(f"The {self.__brand} TV is on.")

    def get_brand(self):          # getter exposes private safely
        return self.__brand

my_tv = Television()
print("Brand:", my_tv.get_brand())   # access via getter — correct way

# %% [markdown]
# ### Nested Classes
#
# A **nested class** is a class defined inside another class. The inner class is only accessible through the outer class.
#
# ```
#   Television (outer class)
#   │
#   ├── volume, channels    (Television attributes)
#   ├── turn_on()           (Television method)
#   └── Remote (nested class)
#        ├── battery_percentage
#        ├── change_channel()
#        └── increase_volume()
# ```

# %%
# Ex 13.32 - Nested Classes
class Television:
    def __init__(self):
        self.volume   = 15
        self.channels = {1: "Aljezzira", 2: "BBC", 3: "CNN"}
        self.remote   = self.Remote(self)   # create nested object

    def turn_on(self):
        print("The TV is on.")

    class Remote:    # nested class
        def __init__(self, television):
            self.battery_percentage = 100
            self.television = television

        def change_channel(self, channel):
            print(f"Changing channel to {self.television.channels[channel]}")

        def increase_volume(self):
            self.television.volume += 1
            print("Increasing volume:", self.television.volume)

tv = Television()
tv.turn_on()
tv.remote.change_channel(2)
tv.remote.increase_volume()

# %%
# Ex 13.33 - Garbage Collection
# Python automatically frees memory for objects with no references.
import gc

print("Garbage collector enabled?:", gc.isenabled())  # True by default
gc.disable()
print("After disable:", gc.isenabled())                # False
gc.enable()
print("After enable:",  gc.isenabled())                # True

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.5 — Private Balance (Encapsulation)</h4>
#   <p>Create a <code>BankAccount</code> class where the <code>balance</code> property <strong>cannot be modified directly from outside the class</strong>:</p>
#   <ul>
#     <li>Store balance as a private attribute <code>__balance</code></li>
#     <li>Provide a getter <code>get_balance()</code> that returns the balance</li>
#     <li>Provide a setter <code>set_balance(amount)</code> that only accepts non-negative amounts</li>
#     <li>Demonstrate that <code>account.__balance = 9999</code> from outside the class does NOT actually change the internal balance (name mangling in action)</li>
#     <li>Print the object's <code>__dict__</code> to reveal the mangled attribute name <code>_BankAccount__balance</code></li>
#   </ul>
# </div>

# %%
# Exercise 13.5 - write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.6 — Nested SavingAccount inside BankAccount</h4>
#   <p>Create a <code>BankAccount</code> outer class with a <code>SavingAccount</code> nested class inside it:</p>
#   <ul>
#     <li><code>BankAccount</code>: holds <code>account_number</code>, <code>balance</code>, method <code>deposit(amount)</code></li>
#     <li><code>SavingAccount</code> (nested): holds <code>interest_rate</code> (e.g., 0.07), method <code>calculate_interest(balance)</code> that returns <code>balance * interest_rate</code></li>
#     <li>Create a <code>BankAccount</code> object with <code>R5000</code> balance, then create a <code>SavingAccount</code> object through it</li>
#     <li>Calculate the interest earned after one year and print the total balance including interest</li>
#     <li><strong>Bonus:</strong> loop for 5 years, applying compound interest each year (interest is added to balance before the next year's calculation)</li>
#   </ul>
# </div>

# %%
# Exercise 13.6 - write your code here

# %% [markdown]
# <div style='border: 2px solid #17a2b8; border-radius: 12px; padding: 20px; background: #e8f8fc; margin: 20px 0;'>
#   <h4 style='color: #17a2b8; margin-top: 0;'>🎯 Practice Zone — Lesson 4: Encapsulation, Nested Classes & Garbage Collection</h4>
#   <p style='margin-bottom: 12px;'>Consolidate access control and nested class patterns:</p>
#
#   <p><strong>🟢 Simple</strong></p>
#   <ol>
#     <li>Create a <code>Student</code> class with <code>__grade</code> as private. Only allow grades 0–100. Use <code>set_grade()</code> and <code>get_grade()</code>. Try setting <code>-5</code> and <code>105</code> — both should print an error.</li>
#     <li>Create a class <code>SafeList</code> with a private list <code>__items</code>. Expose it only through <code>add(item)</code>, <code>remove(item)</code>, and <code>view()</code> methods — prevent direct assignment from outside.</li>
#     <li>Call <code>import gc; gc.disable(); gc.enable()</code> in a cell and explain in a comment what each line does and when manual garbage collection might be useful.</li>
#   </ol>
#
#   <p><strong>🟡 Medium</strong></p>
#   <ol>
#     <li>Build a <code>Hospital</code> outer class with a <code>Patient</code> nested class. <code>Hospital</code> stores a list of patients; <code>Patient</code> has <code>name</code>, <code>diagnosis</code>, and a private <code>__medical_record</code>. Only the hospital can access the medical record via a method.</li>
#     <li>Create a <code>Company</code> class with a nested <code>Employee</code> class. <code>Company</code> tracks all employees; <code>Employee</code> has private <code>__salary</code>. Add <code>give_raise(percent)</code> method. Demonstrate that salary cannot be accessed directly from outside.</li>
#     <li>Write a class <code>ImmutablePoint</code> where both <code>x</code> and <code>y</code> are set in the constructor as private and have ONLY getters (no setters). Try to change them from outside and observe the effect of name mangling.</li>
#   </ol>
#
#   <p><strong>🔴 Hard</strong></p>
#   <ol>
#     <li>Implement an <code>AuditLog</code> class where every access to a private variable is automatically logged. Override <code>__getattribute__</code> so every attribute read appends to a log list. Print the full log at the end.</li>
#     <li>Build a <code>Tree</code> class with a nested <code>Node</code> class. <code>Node</code> has <code>value</code> and <code>children</code>. Add methods to <code>Tree</code>: <code>add_child(parent_val, child_val)</code> and <code>print_tree(node, indent=0)</code> that prints the tree structure with indentation. Build a tree of depth 3.</li>
#     <li>Create a <code>Cache</code> class with a nested <code>CacheEntry</code> class. <code>CacheEntry</code> stores <code>key, value, created_at</code>. The outer <code>Cache</code> auto-expires entries older than 60 seconds (use <code>time.time()</code>). Add <code>set(key, val)</code>, <code>get(key)</code>, and <code>cleanup()</code> methods.</li>
#   </ol>
# </div>

# %%
# Practice Zone — Lesson 4: write your solutions here

# %% [markdown]
# ---
# ## 🧬 Lesson 5 — Inheritance
#
# **Inheritance** lets a new class (child) reuse all the variables, methods, and constructors of an existing class (parent).
#
# ```
#   Benefits:
#   • Code reusability  — don't rewrite methods that already exist
#   • Less development time
#   • Reduced code repetition
#
#   Terminology:
#   ┌────────────────────────────┬────────────────────────────────┐
#   │  Existing class (parent)   │  New class (child)             │
#   ├────────────────────────────┼────────────────────────────────┤
#   │  Super class               │  Sub class                     │
#   │  Base class                │  Derived class                 │
#   │  Parent class              │  Child class                   │
#   └────────────────────────────┴────────────────────────────────┘
#
#   3 Types of Inheritance:
#   ┌───────────────────────────────────────────────────────────────┐
#   │  Single      →  1 parent  →  1 child                         │
#   │  Multi-level →  Grandparent → Parent → Child (chain)         │
#   │  Multiple    →  2+ parents → 1 child                         │
#   └───────────────────────────────────────────────────────────────┘
#
#   Syntax: class Child(Parent):
# ```
#
# ### Single Inheritance
#
# ```
#   Television (parent)
#       │
#       └──► Flat_TV (child) — inherits turn_on(), change_channel()
#                              adds its own HDMI_mode()
# ```

# %%
# Ex 13.35 - Single Inheritance
class Television:            # PARENT
    def __init__(self):
        self.channels = {1: "Aljezzira", 2: "BBC", 3: "CNN"}

    def turn_on(self):
        print("The TV is on.")

    def change_channel(self, channel):
        print(f"Changing to {self.channels[channel]}")

class Flat_TV(Television):   # CHILD — inherits from Television
    def HDMI_mode(self):
        self.mode = "HDMI"
        print("Mode :", self.mode)

my_flat_tv = Flat_TV()
my_flat_tv.turn_on()          # inherited from Television
my_flat_tv.change_channel(3)  # inherited from Television
my_flat_tv.HDMI_mode()        # own method

# %% [markdown]
# ### Multilevel Inheritance
#
# ```
#   Television (grandparent)
#       │
#       └──► Flat_TV (parent)  — adds HDMI_mode()
#                 │
#                 └──► Smart_TV (child) — adds connect_to_netflix()
#
#   Smart_TV inherits from BOTH Flat_TV AND Television.
# ```

# %%
# Ex 13.36 - Multilevel Inheritance
class Television:
    def __init__(self):
        self.channels = {1: "Aljezzira", 2: "BBC", 3: "CNN"}

    def turn_on(self):         print("The TV is on.")
    def change_channel(self, c): print(f"Changing to {self.channels[c]}")

class Flat_TV(Television):
    def HDMI_mode(self):       print("Mode : HDMI")

class Smart_TV(Flat_TV):      # inherits from Flat_TV (and Television)
    def connect_to_netflix(self): print("Connecting to Netflix...")

my_smart_tv = Smart_TV()
my_smart_tv.turn_on()            # from Television
my_smart_tv.change_channel(3)    # from Television
my_smart_tv.HDMI_mode()          # from Flat_TV
my_smart_tv.connect_to_netflix() # own method

# %% [markdown]
# ### Multiple Inheritance
#
# ```
#   Television (parent 1)    Smart_Speaker (parent 2)
#         │                         │
#         └─────────────────────────┘
#                      │
#                  Smart_TV (child)
#
#   When BOTH parents have the same method name,
#   the ORDER in the class definition decides which one is used:
#
#   class Smart_TV(Television, Smart_Speaker)  → Television.method wins
#   class Smart_TV(Smart_Speaker, Television)  → Smart_Speaker.method wins
# ```

# %%
# Ex 13.37 - Multiple Inheritance
class Television:
    def __init__(self):
        self.volume   = 15
        self.channels = {1: "Aljezzira", 2: "BBC", 3: "CNN"}

    def turn_on(self):         print("The TV is on.")
    def change_channel(self, c): print(f"Channel: {self.channels[c]}")

class Smart_Speaker:
    def increase_volume(self):
        self.volume += 1
        print("Volume :", self.volume)

class Smart_TV(Television, Smart_Speaker):  # inherits from BOTH
    def connect_to_netflix(self): print("Connecting to Netflix...")

my_smart_tv = Smart_TV()
my_smart_tv.turn_on()
my_smart_tv.change_channel(3)
my_smart_tv.increase_volume()    # from Smart_Speaker
my_smart_tv.connect_to_netflix()

# %%
# Ex 13.38 & 13.39 - Order of inheritance determines method priority
class Television:
    def __init__(self): self.volume = 15
    def increase_volume(self):
        self.volume += 1
        print("TV Volume :", self.volume)

class Smart_Speaker:
    def increase_volume(self):
        self.volume += 1
        print("Speaker Volume :", self.volume)

# Case 1: Television first → TV volume
class Smart_TV_A(Television, Smart_Speaker):
    pass

# Case 2: Smart_Speaker first → Speaker volume
class Smart_TV_B(Smart_Speaker, Television):
    pass

print("Case 1 (Television first):")
Smart_TV_A().increase_volume()

print("\nCase 2 (Smart_Speaker first):")
Smart_TV_B().increase_volume()

# %% [markdown]
# ---
# ## 🦆 Lesson 6 — Polymorphism
#
# **Polymorphism** = *poly* (many) + *morphs* (forms). It is the ability of an object to take on many forms.
#
# ```
#   Types of Polymorphism in Python:
#   ┌────────────────────────────────────────────────────────────────┐
#   │  1. Overriding                                                 │
#   │     1.1 Method Overriding   — child redefines parent method    │
#   │     1.2 Constructor Overriding — child redefines __init__      │
#   │                                                                │
#   │  2. Overloading (not native — use alternatives)               │
#   │     2.1 Method Overloading    — same name, diff params        │
#   │     2.2 Constructor Overloading                               │
#   │     2.3 Operator Overloading  — +, * used for different types │
#   │                                                                │
#   │  3. Duck Typing Philosophy                                     │
#   └────────────────────────────────────────────────────────────────┘
# ```
#
# ### 1.1 Method Overriding

# %%
# Ex 13.40 - Method Overriding — child replaces parent's method
class Smart_Speaker:
    def __init__(self): self.volume = 15

    def increase_volume(self):
        self.volume += 1
        print(f"Smart Speaker Volume : {self.volume}")

class Smart_TV(Smart_Speaker):
    def increase_volume(self):    # OVERRIDES parent's method
        self.volume += 1
        print(f"Smart TV Volume : {self.volume}")

my_smart_tv = Smart_TV()
my_smart_tv.increase_volume()    # child's version is called

# %% [markdown]
# ### The `super()` Function
#
# `super()` lets you call the **parent class constructor, methods, or variables** from inside the child class.
#
# ```
#   Use cases:
#   ┌────────────────────────────────────────────────────────────────┐
#   │  super().__init__()       → call parent's constructor          │
#   │  super().method_name()    → call parent's method               │
#   │  super().variable_name    → access parent's static variable    │
#   └────────────────────────────────────────────────────────────────┘
# ```

# %%
# Ex 13.42 - Calling parent constructor from child using super()
class Smart_Speaker:
    def __init__(self):
        self.volume = 15
        print("Default Smart Speaker Volume :", self.volume)

class Smart_TV(Smart_Speaker):
    def __init__(self):
        self.volume = 20
        super().__init__()    # also runs parent __init__
        print("Smart TV Volume :", self.volume)

my_smart_tv = Smart_TV()
# Note: super().__init__() resets self.volume to 15

# %%
# Ex 13.43 - Calling parent method from child method using super()
class Smart_Speaker:
    volume = 15
    def increase_volume(self):
        self.volume += 1
        print("Smart Speaker Volume :", self.volume)

class Smart_TV(Smart_Speaker):
    volume = 20
    def increase_volume(self):
        super().increase_volume()   # call parent method first
        print("Smart TV Volume :", self.volume)

my_smart_tv = Smart_TV()
my_smart_tv.increase_volume()

# %%
# Ex 13.45 - Accessing parent's variable using super()
class Smart_Speaker:
    volume = 15

class Smart_TV(Smart_Speaker):
    volume = 20
    def increase_volume(self):
        self.volume = super().volume + 1   # use PARENT's volume (15), not own (20)
        print("Smart TV Volume :", self.volume)

Smart_TV().increase_volume()   # 15 + 1 = 16

# %% [markdown]
# ### 2.3 Operator Overloading
#
# Python already supports operator overloading — the `+` and `*` operators work differently depending on the data type:

# %%
# Ex 13.52 - '+' Operator Overloading
print(10 + 20)                   # arithmetic addition
print("Python" + "Programming") # string concatenation
print([1, 2, 3] + [4, 5, 6])    # list concatenation

print()
# Ex 13.53 - '*' Operator Overloading
print(10 * 20)             # multiplication
print("Python" * 3)        # string repetition
print([1, 2, 3] * 3)       # list repetition

# %% [markdown]
# ### 3. Duck Typing Philosophy
#
# > *"If it walks like a duck, swims like a duck, and quacks like a duck — then it probably is a duck."*
#
# **Duck typing** means the type of an object is less important than whether it has the expected methods. Python doesn't check *what* the object is — only *what it can do*.

# %%
# Ex 13.54 - Duck Typing — one Remote, controls both TV and Speaker
class Television:
    volume = 20
    def increase_volume(self):
        self.volume += 1
        print("Smart TV Volume :", self.volume)

class Speaker:
    volume = 15
    def increase_volume(self):
        self.volume += 1
        print("Smart Speaker Volume :", self.volume)

class Remote:
    def volume_up(self, device):    # accepts ANY object with increase_volume()
        device.increase_volume()    # duck typing — doesn't check type

remote = Remote()
remote.volume_up(Television())  # works on TV
remote.volume_up(Speaker())     # works on Speaker too!

# %% [markdown]
# ---
# ## 🎭 Lesson 7 — Abstraction and Interfaces
#
# ### What is Abstraction?
#
# **Abstraction** simplifies complex systems by showing only the essential details and hiding implementation. Like a TV remote — you press a button without knowing the internal circuitry.
#
# ```
#   Method Types:
#   ┌───────────────────┬────────────────────────────────────────────────┐
#   │  Implemented      │  Has both name AND body  →  concrete method    │
#   │  Unimplemented    │  Has only name, NO body  →  abstract method    │
#   └───────────────────┴────────────────────────────────────────────────┘
#
#   Abstract Class Rules:
#   ┌─────────────────────────────────────────────────────────────────────┐
#   │  • Import ABC and abstractmethod from abc module                    │
#   │  • Class must inherit from ABC                                      │
#   │  • Decorate abstract methods with @abstractmethod                   │
#   │  • Abstract methods must use pass in the body                       │
#   │  • Child class MUST implement all abstract methods                  │
#   │  • Cannot create objects directly from an abstract class            │
#   └─────────────────────────────────────────────────────────────────────┘
#
#   Abstract Class vs Interface:
#   ┌──────────────────────┬───────────────────────────────────────────────┐
#   │  Abstract Class      │  Some implemented + some abstract methods     │
#   │                      │  Use when: partial implementation is known    │
#   ├──────────────────────┼───────────────────────────────────────────────┤
#   │  Interface           │  ONLY abstract methods (no implementation)   │
#   │                      │  Use when: NO implementation details known   │
#   └──────────────────────┴───────────────────────────────────────────────┘
# ```

# %%
# Ex 13.55 - Abstract Class with Abstract Method
from abc import ABC, abstractmethod

class Television(ABC):       # abstract class
    def __init__(self):
        self.volume = 15

    def power_on(self):      # concrete method — has body
        print("The TV is powered on.")

    @abstractmethod
    def increase_volume(self):  # abstract method — no body
        pass

# Cannot create Television object directly:
try:
    tv = Television()
except TypeError as e:
    print("Cannot instantiate abstract class:", e)

# %%
# Child class MUST implement all abstract methods
class SmartTV(Television):
    def increase_volume(self):     # implements the abstract method
        self.volume += 1
        print("Smart TV Volume :", self.volume)

    def decrease_volume(self):
        self.volume -= 1
        print("Smart TV Volume :", self.volume)

my_smart_tv = SmartTV()        # can create child class objects
my_smart_tv.power_on()         # inherited concrete method
my_smart_tv.increase_volume()  # implemented abstract method
my_smart_tv.decrease_volume()

# %%
# Ex 13.57 - Interface (abstract class with ONLY abstract methods)
from abc import ABC, abstractmethod

class Television(ABC):       # interface — all methods are abstract
    def __init__(self):
        self.volume   = 15
        self.channels = {1: "Aljezzira", 2: "BBC", 3: "CNN"}

    def power_on(self):      # unimplemented (interface-style)
        pass

    @abstractmethod
    def increase_volume(self):
        pass

class SmartTV(Television):   # must implement all abstract methods
    def power_on(self):
        print("The TV is powered on.")

    def increase_volume(self):
        self.volume += 1
        print("Smart TV Volume :", self.volume)

    def decrease_volume(self):
        self.volume -= 1
        print("Smart TV Volume :", self.volume)

my_smart_tv = SmartTV()
my_smart_tv.power_on()
my_smart_tv.increase_volume()
my_smart_tv.decrease_volume()

# %% [markdown]
# ---
# ## 📝 Exercises and Extra Challenges
#
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.7 — Banking Inheritance (Single)</h4>
#   <p>Create <code>BankBranch</code> as a parent class with <code>branch_name</code>, <code>open_account()</code>, and <code>deposit(amount)</code>. Create <code>BankHQ</code> as a child that adds <code>audit_branches()</code>.</p>
# </div>

# %%
# Exercise 13.7 - Single Inheritance — write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.8 — Banking Inheritance (Multilevel)</h4>
#   <p>Extend Exercise 13.7: make <code>BankHQ</code> a grandparent, <code>BankBranch</code> a parent, and <code>BankAccount</code> a child with <code>balance</code>, <code>deposit()</code>, and <code>withdraw()</code>.</p>
# </div>

# %%
# Exercise 13.8 - Multilevel Inheritance — write your code here

# %% [markdown]
# <div style='border: 2px solid #28a745; border-radius: 12px; padding: 20px; background: #f0fff4; margin: 20px 0;'>
#   <h4 style='color: #28a745; margin-top: 0;'>✏️ Exercise 13.10 — Savings Account with Override</h4>
#   <p>Implement a <code>BankAccount</code> class with <code>deposit(amount)</code>, <code>withdraw(amount)</code>, <code>get_balance()</code>. Then implement a <code>SavingAccount</code> class that:</p>
#   <ul>
#     <li>Inherits from <code>BankAccount</code></li>
#     <li>Adds <code>interest_rate</code> property</li>
#     <li>Adds <code>calculate_interest()</code> method</li>
#     <li>Overrides <code>withdraw(amount)</code> to enforce a withdrawal limit</li>
#   </ul>
# </div>

# %%
# Exercise 13.10 - write your code here

# %% [markdown]
# <div style='border: 2px solid #6f42c1; border-radius: 12px; padding: 20px; background: #f5f0ff; margin: 20px 0;'>
#   <h4 style='color: #6f42c1; margin-top: 0;'>🏆 Challenge 3 — School Management System (Advanced)</h4>
#   <p>Build a <strong>complete school management platform</strong> that exercises every OOP concept from this chapter simultaneously. This challenge is deliberately comprehensive — apply all 7 pillars: classes, encapsulation, inheritance, polymorphism, abstraction, nested classes, and static/class methods.</p>
#
#   <p><strong>Class hierarchy to build:</strong></p>
#   <ul>
#     <li><code>Auditable</code> (mixin class): static variable <code>_audit_log = []</code> and static method <code>log(entry)</code> that appends a timestamped string to the log; static method <code>get_audit_log()</code></li>
#     <li><code>Person(ABC, Auditable)</code> (abstract base, uses multiple inheritance with mixin):
#       <ul>
#         <li>Private <code>__name</code> and <code>__id_number</code> with getters only (immutable after construction)</li>
#         <li>Protected <code>_age</code> with setter that validates age is between 5 and 120</li>
#         <li>Abstract method <code>introduce()</code></li>
#         <li>Abstract method <code>get_role()</code> that returns a string</li>
#         <li><code>__str__</code> and <code>__repr__</code></li>
#       </ul>
#     </li>
#     <li><code>Student(Person)</code>:
#       <ul>
#         <li>Private <code>__grades</code> dict: <code>{subject: [marks]}</code></li>
#         <li>Method <code>add_grade(subject, mark)</code>: validates mark is 0–100, logs the action via <code>Auditable.log()</code></li>
#         <li>Method <code>average(subject)</code>: returns average mark or <code>None</code> if subject not found</li>
#         <li>Method <code>overall_average()</code>: average of all subject averages</li>
#         <li>Method <code>get_symbol()</code>: returns <code>"A"</code> (≥80), <code>"B"</code> (≥70), <code>"C"</code> (≥60), <code>"D"</code> (≥50), <code>"F"</code> (below 50) based on overall average</li>
#         <li>Implements <code>introduce()</code> and <code>get_role()</code></li>
#       </ul>
#     </li>
#     <li><code>Teacher(Person)</code>:
#       <ul>
#         <li>Private <code>__salary</code> with getter and validated setter (no negative salary)</li>
#         <li>Instance attribute <code>subjects</code>: list of subjects taught</li>
#         <li>Method <code>add_subject(subject)</code></li>
#         <li>Method <code>give_raise(percent)</code>: increases salary by percent; logs the action</li>
#         <li>Implements <code>introduce()</code> and <code>get_role()</code></li>
#       </ul>
#     </li>
#     <li><code>HeadTeacher(Teacher)</code>:
#       <ul>
#         <li>Adds <code>school_name</code> attribute</li>
#         <li>Overrides <code>give_raise(percent)</code> to apply 1.5× the normal raise (head teachers get a premium) — use <code>super()</code></li>
#         <li>Method <code>address_school(message)</code> that prints an announcement</li>
#         <li>Overrides <code>get_role()</code> to return <code>"Head Teacher"</code></li>
#       </ul>
#     </li>
#     <li><code>School</code> (outer class with nested classes):
#       <ul>
#         <li>Static variable <code>_schools_count = 0</code> (class method <code>get_count()</code>)</li>
#         <li>Instance attributes: <code>name</code>, <code>address</code></li>
#         <li>Private <code>__students = []</code>, <code>__teachers = []</code></li>
#         <li>Method <code>enroll(student)</code>: validates the argument IS a <code>Student</code> instance; logs enrollment</li>
#         <li>Method <code>hire(teacher)</code>: validates the argument IS a <code>Teacher</code> instance; logs hire</li>
#         <li>Method <code>print_roster()</code>: prints all students (with symbol) and teachers (with subjects) in a formatted table</li>
#         <li>Method <code>top_student()</code>: returns the student with the highest overall average</li>
#         <li>Method <code>subjects_offered()</code>: returns a sorted set of all subjects across all teachers</li>
#         <li><strong>Nested class <code>Timetable</code></strong>:
#           <ul>
#             <li>Holds a dict <code>{day: [subjects]}</code></li>
#             <li>Method <code>add_period(day, subject)</code></li>
#             <li>Method <code>view_day(day)</code> prints the schedule for that day</li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#   </ul>
#
#   <p><strong>Polymorphism demonstration:</strong></p>
#   <ul>
#     <li>Create a mixed list of <code>Student</code>, <code>Teacher</code>, and <code>HeadTeacher</code> objects</li>
#     <li>Loop through the list calling <code>introduce()</code> and <code>get_role()</code> on each — without any <code>isinstance()</code> check (pure polymorphism)</li>
#     <li>Write a duck-typing function <code>process_person(person)</code> that calls <code>person.introduce()</code> — works on any <code>Person</code> subclass</li>
#   </ul>
#
#   <p><strong>Demonstrate the full system:</strong></p>
#   <ol>
#     <li>Create a <code>School</code> with name and address</li>
#     <li>Hire 2 teachers and 1 head teacher; each should teach at least 2 subjects</li>
#     <li>Enroll 4 students; add at least 3 grades per student across at least 3 subjects</li>
#     <li>Create a <code>Timetable</code> inside the school and fill in 3 days</li>
#     <li>Print the full roster using <code>print_roster()</code></li>
#     <li>Print the top student and their overall average + symbol</li>
#     <li>Print all subjects offered at the school</li>
#     <li>Print the full audit log to show every action was tracked</li>
#   </ol>
#
#   <p><strong>Bonus:</strong></p>
#   <ul>
#     <li>Add a <code>GraduateStudent(Student)</code> with a <code>thesis_topic</code> attribute and override <code>get_symbol()</code> to use a stricter scale (A ≥ 85)</li>
#     <li>Override <code>__eq__</code> on <code>Person</code> so two Person objects are equal if and only if their <code>id_number</code> matches</li>
#     <li>Show the MRO of <code>HeadTeacher</code> using <code>HeadTeacher.__mro__</code></li>
#   </ul>
# </div>

# %%
# Challenge 3 - School Management System (Advanced)
from abc import ABC, abstractmethod
from datetime import datetime

# write your code here

# %% [markdown]
# ---
# ## 🗝️ Key Takeaways
#
# <div style='border: 2px solid #6c757d; border-radius: 12px; padding: 20px; background: #f8f9fa; margin: 20px 0;'>
#   <h3 style='color: #6c757d; margin-top: 0;'>📋 Key Takeaways — Chapter 13: Object-Oriented Programming</h3>
#   <table style='width:100%; border-collapse: collapse;'>
#     <tr style='background:#e9ecef;'><th style='padding:8px; text-align:left;'>Concept</th><th style='padding:8px; text-align:left;'>Key Point</th></tr>
#     <tr><td style='padding:8px;'><strong>OOP</strong></td><td style='padding:8px;'>Programs organised as reusable <strong>objects</strong> — each with data (attributes) and behaviour (methods). Python supports both OOP and functional styles.</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Class vs Object</strong></td><td style='padding:8px;'>A <strong>class</strong> is the blueprint (Television); an <strong>object</strong> is a real instance made from it (<code>my_tv = Television()</code>). One blueprint, many objects.</td></tr>
#     <tr><td style='padding:8px;'><strong>Constructor <code>__init__</code></strong></td><td style='padding:8px;'>Special method auto-called when an object is created. Used to initialise instance variables. Takes <code>self</code> plus optional parameters.</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>self</strong></td><td style='padding:8px;'>Default reference to the current object. Lets methods access and modify the specific object's data. Convention only — not a Python keyword.</td></tr>
#     <tr><td style='padding:8px;'><strong>Variable types</strong></td><td style='padding:8px;'><strong>Instance</strong> (<code>self.brand</code>): unique per object. <strong>Static</strong> (<code>Television.display</code>): shared by all. <strong>Local</strong>: temporary, only exists inside the method.</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Method types</strong></td><td style='padding:8px;'><strong>Instance</strong> (first param: <code>self</code>). <strong>Class method</strong> (<code>@classmethod</code>, first param: <code>cls</code>). <strong>Static</strong> (<code>@staticmethod</code>, no implicit param).</td></tr>
#     <tr><td style='padding:8px;'><strong>Setter &amp; Getter</strong></td><td style='padding:8px;'>Setter (mutator) validates then sets a value; Getter (accessor) returns it. Protects data by controlling how it is read or changed.</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Encapsulation</strong></td><td style='padding:8px;'>Hides internal data: <code>public</code> (no prefix), <code>_protected</code> (one underscore), <code>__private</code> (two underscores — name-mangled to <code>_Class__attr</code>).</td></tr>
#     <tr><td style='padding:8px;'><strong>Nested class</strong></td><td style='padding:8px;'>A class defined inside another class. Access via the outer object: <code>tv.remote.change_channel(2)</code>. Useful for tightly coupled components.</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Inheritance</strong></td><td style='padding:8px;'>Child reuses parent's code. <strong>Single</strong>: 1 parent. <strong>Multilevel</strong>: chain (grandparent → parent → child). <strong>Multiple</strong>: 2+ parents. Syntax: <code>class Child(Parent)</code>.</td></tr>
#     <tr><td style='padding:8px;'><strong>super()</strong></td><td style='padding:8px;'>Calls the parent's constructor (<code>super().__init__()</code>), method (<code>super().method()</code>), or accesses a parent static variable (<code>super().var</code>) from inside the child class.</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Overriding</strong></td><td style='padding:8px;'>Child redefines a method with the same name as the parent. The child version is called when using a child object. Use <code>super()</code> to still call the parent version.</td></tr>
#     <tr><td style='padding:8px;'><strong>Duck Typing</strong></td><td style='padding:8px;'>"If it has the method, use it." Python doesn't check type — only whether the expected method exists. Enables flexible, type-agnostic code.</td></tr>
#     <tr style='background:#f8f9fa;'><td style='padding:8px;'><strong>Abstraction / Interface</strong></td><td style='padding:8px;'>Use <code>from abc import ABC, abstractmethod</code>. <strong>Abstract class</strong>: mix of abstract + concrete methods. <strong>Interface</strong>: only abstract methods. Child classes must implement all abstract methods.</td></tr>
#   </table>
# </div>

# %% [markdown]
# <div style='background: linear-gradient(135deg, #1a1a2e, #16213e); padding: 25px; border-radius: 12px; text-align: center; margin-top: 30px;'>
#   <p style='color: #a0c4ff; margin: 0 0 10px;'>You have completed Chapter 13 — Object-Oriented Programming</p>
#   <div style='display: flex; justify-content: center; gap: 30px; flex-wrap: wrap;'>
#     <span style='color: #666;'>← Chapter 12: Dictionary</span>
#     <span style='color: #00d4ff; font-weight: bold;'>📍 Chapter 13: OOP</span>
#     <span style='color: #666;'>Chapter 14: Exception Handling →</span>
#   </div>
#   <p style='color: #888; margin: 15px 0 0; font-size: 0.85em;'>DAQSLearn Platform | N³ Smart Solutions | Python Programming by Ncube.T</p>
# </div>
